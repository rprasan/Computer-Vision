# %% [markdown]
# # CPSC 8810 Project 2-2: Two Layer Neural Network
#
# Before we start, please put your name and CUID in following format
#
# : Firstname LASTNAME, #00000000   //   e.g.) Justin JOHNSON, #12345678

# %% [markdown]
# **Your Answer:**
# Rahul PRASANNA KUMAR, #88672821

# %% [markdown]
# # Setup Code
# Before getting started, we need to run some boilerplate code to set up our environment, same as Assignment 1. You'll need to rerun this setup code each time you start the notebook.
#
# First, run this cell load the autoreload extension. This allows us to edit .py source files, and re-import them into the notebook for a seamless editing and debugging experience.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Google Colab Setup
# Next we need to run a few commands to set up our environment on Google Colab. If you are running this notebook on a local machine you can skip this section.
#
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account (the same account you used to store this notebook!) and copy the authorization code into the text box that appears below.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Now recall the path in your Google Drive where you uploaded this notebook, fill it in below. If everything is working correctly then running the folowing cell should print the filenames from the assignment:
#
# ```
# ['two_layer_net.ipynb', 'cpsc8810', 'two_layer_net.py', 'linear_classifier.py', 'linear_classifier.ipynb', 'challenge_problem.py']
# ```

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a 2020FA folder and put all the files under A2 folder, then '2020FA/A2'
# GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = '2020FA/A2'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'Colab Notebooks/Computer Vision/Project 2'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['cpsc8810', '.ipynb_checkpoints', '__pycache__', 'linear_classifier.py', 'two_layer_net.py', 'hand_drawn_weights1.jpeg', 'hand_drawn_weights.jpeg', 'hand_drawn_weights3.jpeg', 'hand_drawn_weights4.jpeg', 'hand_drawn_weights5.jpeg', 'hand_drawn_weights6.jpeg', 'hand_drawn_weights7.jpeg', 'challenge_problem.ipynb', 'svm_best_model.pt', 'softmax_best_model.pt', 'linear_classifier.ipynb', 'two_layer_net.ipynb']

# %% [markdown]
# Once you have successfully mounted your Google Drive and located the path to this assignment, run th following cell to allow us to import from the `.py` files of this assignment. If it works correctly, it should print the message:
#
# ```
# Hello from two_layer_net.py!
# Hello from a2_helpers.py!
# ```
#
# as well as the last edit time for the file `two_layer_net.py`.

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

import time, os
os.environ["TZ"] = "US/Eastern"
time.tzset()

from two_layer_net import hello_two_layer_net
hello_two_layer_net()

from cpsc8810.a2_helpers import hello_helper
hello_helper()

two_layer_net_path = os.path.join(GOOGLE_DRIVE_PATH, 'two_layer_net.py')
two_layer_net_edit_time = time.ctime(os.path.getmtime(two_layer_net_path))
print('two_layer_net.py last edited on %s' % two_layer_net_edit_time)
# Out:
# Hello from two_layer_net.py!
# Hello from a2_helpers.py!
# two_layer_net.py last edited on Mon Oct 10 02:51:34 2022

# %% [markdown]
# ## Miscellaneous

# %% [markdown]
# Run some setup code for this notebook: Import some useful packages and increase the default figure size.

# %%
import cpsc8810
import torch
import matplotlib.pyplot as plt
import statistics
import random
import time
# %matplotlib inline


plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['font.size'] = 16
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# We will use GPUs to accelerate our computation in this notebook. Run the following to make sure GPUs are enabled:

# %%
if torch.cuda.is_available:
  print('Good to go!')
else:
  print('Please set GPU via Edit -> Notebook Settings.')
# Out:
# Good to go!

# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.
#
# We train the network with a softmax loss function and L2 regularization on the weight matrices. The network uses a ReLU nonlinearity after the first fully connected layer.
#
# In other words, the network has the following architecture:
#
#   input - fully connected layer - ReLU - fully connected layer - softmax
#
# The outputs of the second fully-connected layer are the scores for each class.
#
# **Note**: When you implment the regularization over W, **please DO NOT multiply the regularization term by 1/2** (no coefficient).

# %% [markdown]
# ## Play with a toy data

# %% [markdown]
# The inputs to our network will be a batch of $N$ (`num_inputs`) $D$-dimensional vectors (`input_size`); the hidden layer will have $H$ hidden units (`hidden_size`), and we will predict classification scores for $C$ categories (`num_classes`). This means that the learnable weights and biases of the network will have the following shapes:
#
# *   W1: First layer weights; has shape (D, H)
# *   b1: First layer biases; has shape (H,)
# *   W2: Second layer weights; has shape (H, C)
# *   b2: Second layer biases; has shape (C,)
#
# We will use `a2_helpers.get_toy_data` function to generate random weights for a small toy model while we implement the model.

# %% [markdown]
# ### Forward pass: compute scores
# Like in the Linear Classifiers exercise, we want to write a function that takes as input the model weights and a batch of images and labels, and returns the loss and the gradient of the loss with respect to each model parameter.
#
# However rather than attempting to implement the entire function at once, we will take a staged approach and ask you to implement the full forward and backward pass one step at a time.
#
# First we will implement the forward pass of the network which uses the weights and biases to compute scores for all inputs in `nn_forward_pass`.

# %% [markdown]
# Compute the scores and compare with the answer. The distance gap should be smaller than 1e-10.

# %%
import cpsc8810
from cpsc8810.a2_helpers import get_toy_data
from two_layer_net import nn_forward_pass

cpsc8810.reset_seed(0)
toy_X, toy_y, params = get_toy_data()

# YOUR_TURN: Implement the score computation part of nn_forward_pass
scores, _ = nn_forward_pass(params, toy_X)
print('Your scores:')
print(scores)
print(scores.dtype)
print()
print('correct scores:')
correct_scores = torch.tensor([
        [ 9.7003e-08, -1.1143e-07, -3.9961e-08],
        [-7.4297e-08,  1.1502e-07,  1.5685e-07],
        [-2.5860e-07,  2.2765e-07,  3.2453e-07],
        [-4.7257e-07,  9.0935e-07,  4.0368e-07],
        [-1.8395e-07,  7.9303e-08,  6.0360e-07]], dtype=torch.float32, device=scores.device)
print(correct_scores)
print()

# The difference should be very small. We get < 1e-10
scores_diff = (scores - correct_scores).abs().sum().item()
print('Difference between your scores and correct scores: %.2e' % scores_diff)
# Out:
# Your scores:
# tensor([[ 9.7003e-08, -1.1143e-07, -3.9961e-08],
#         [-7.4297e-08,  1.1502e-07,  1.5685e-07],
#         [-2.5860e-07,  2.2765e-07,  3.2453e-07],
#         [-4.7257e-07,  9.0935e-07,  4.0368e-07],
#         [-1.8395e-07,  7.9303e-08,  6.0360e-07]], device='cuda:0')
# torch.float32
#
# correct scores:
# tensor([[ 9.7003e-08, -1.1143e-07, -3.9961e-08],
#         [-7.4297e-08,  1.1502e-07,  1.5685e-07],
#         [-2.5860e-07,  2.2765e-07,  3.2453e-07],
#         [-4.7257e-07,  9.0935e-07,  4.0368e-07],
#         [-1.8395e-07,  7.9303e-08,  6.0360e-07]], device='cuda:0')
#
# Difference between your scores and correct scores: 2.24e-11

# %% [markdown]
# ### Forward pass: compute loss
# Now, we implement the first part of `nn_forward_backward` that computes the data and regularization loss.
#
# For the data loss, we will use the softmax loss. For the regularization loss we will use L2 regularization on the weight matrices `W1` and `W2`; we will not apply regularization loss to the bias vectors `b1` and `b2`.

# %% [markdown]
# First, Let's run the following to check your implementation.
#
# We compute the loss for the toy data, and compare with the answer computed by our implementation. The difference between the correct and computed loss should be less than `1e-4`.

# %%
import cpsc8810
from cpsc8810.a2_helpers import get_toy_data
from two_layer_net import nn_forward_backward

cpsc8810.reset_seed(0)
toy_X, toy_y, params = get_toy_data()

# YOUR_TURN: Implement the loss computation part of nn_forward_backward
loss, _ = nn_forward_backward(params, toy_X, toy_y, reg=0.05)
print('Your loss: ', loss.item())
correct_loss = 1.0986121892929077
print('Correct loss: ', correct_loss)
diff = (correct_loss - loss).item()

# should be very small, we get < 1e-4
print('Difference: %.4e' % diff)
# Out:
# Your loss:  1.0986121892929077
# Correct loss:  1.0986121892929077
# Difference: 0.0000e+00

# %% [markdown]
# ### Backward pass
# Now implement the backward pass for the entire network in `nn_forward_backward`.
#
# After doing so, we will use numeric gradient checking to see whether the analytic gradient computed by our backward pass mateches a numeric gradient.
#
# We will use the functions `cpsc8810.grad.compute_numeric_gradient` and `cpsc8810.grad.rel_error` to help with numeric gradient checking. We can learn more about these functions using the `help` command:

# %%
help(cpsc8810.grad.compute_numeric_gradient)
print('-' * 80)
help(cpsc8810.grad.rel_error)
# Out:
# Help on function compute_numeric_gradient in module cpsc8810.grad:
#
# compute_numeric_gradient(f, x, dLdf=None, h=1e-07)
#     Compute the numeric gradient of f at x using a finite differences
#     approximation. We use the centered difference:
#
#     df    f(x + h) - f(x - h)
#     -- ~= -------------------
#     dx           2 * h
#
#     Function can also expand this easily to intermediate layers using the
#     chain rule:
#
#     dL   df   dL
#     -- = -- * --
#     dx   dx   df
#
#     Inputs:
#     - f: A function that inputs a torch tensor and returns a torch scalar
#     - x: A torch tensor giving the point at which to compute the gradient
#     - dLdf: optional upstream gradient for intermediate layers
#     - h: epsilon used in the finite difference calculation
#     Returns:
#     - grad: A tensor of the same shape as x giving the gradient of f at x
#
# --------------------------------------------------------------------------------
# Help on function rel_error in module cpsc8810.grad:
#
# rel_error(x, y, eps=1e-10)
#     Compute the relative error between a pair of tensors x and y,
#     which is defined as:
#
#                             max_i |x_i - y_i]|
#     rel_error(x, y) = -------------------------------
#                       max_i |x_i| + max_i |y_i| + eps
#
#     Inputs:
#     - x, y: Tensors of the same shape
#     - eps: Small positive constant for numeric stability
#
#     Returns:
#     - rel_error: Scalar giving the relative error between x and y

# %% [markdown]
# Now we will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check.
#
# You should see relative errors less than `1e-4` for all parameters.

# %%
import cpsc8810
from cpsc8810.a2_helpers import get_toy_data
from two_layer_net import nn_forward_backward

cpsc8810.reset_seed(0)

reg = 0.05
toy_X, toy_y, params = get_toy_data(dtype=torch.float64)

# YOUR_TURN: Implement the gradient computation part of nn_forward_backward
#            When you implement the gradient computation part, you may need to 
#            implement the `hidden` output in nn_forward_pass, as well.
loss, grads = nn_forward_backward(params, toy_X, toy_y, reg=reg)

for param_name, grad in grads.items():
  param = params[param_name]
  f = lambda w: nn_forward_backward(params, toy_X, toy_y, reg=reg)[0]
  grad_numeric = cpsc8810.grad.compute_numeric_gradient(f, param)
  error = cpsc8810.grad.rel_error(grad, grad_numeric)
  print('%s max relative error: %e' % (param_name, error))
# Out:
# W1 max relative error: 1.441750e-06
# b1 max relative error: 8.239303e-06
# W2 max relative error: 1.261262e-06
# b2 max relative error: 3.122771e-09

# %% [markdown]
# ### Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers.
#
# Look at the function `nn_train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers.
#
# You will also have to implement `nn_predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. Your final training loss should be less than 1.0.

# %%
import cpsc8810
from cpsc8810.a2_helpers import get_toy_data
from two_layer_net import nn_forward_backward, nn_train, nn_predict

cpsc8810.reset_seed(0)
toy_X, toy_y, params = get_toy_data()

# YOUR_TURN: Implement the nn_train function.
#            You may need to check nn_predict function (the "pred_func") as well.
stats = nn_train(params, nn_forward_backward, nn_predict, toy_X, toy_y, toy_X, toy_y,
                 learning_rate=1e-1, reg=1e-6,
                 num_iters=200, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'], 'o')
plt.xlabel('Iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.5211756229400635

# %%
# Plot the loss function and train / validation accuracies
plt.plot(stats['train_acc_history'], 'o', label='train')
plt.plot(stats['val_acc_history'], 'o', label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Testing our NN on a real dataset: CIFAR-10
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
import cpsc8810

# Invoke the above function to get our data.
cpsc8810.reset_seed(0)
data_dict = cpsc8810.data.preprocess_cifar10(dtype=torch.float64)
print('Train data shape: ', data_dict['X_train'].shape)
print('Train labels shape: ', data_dict['y_train'].shape)
print('Validation data shape: ', data_dict['X_val'].shape)
print('Validation labels shape: ', data_dict['y_val'].shape)
print('Test data shape: ', data_dict['X_test'].shape)
print('Test labels shape: ', data_dict['y_test'].shape)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar-10-python.tar.gz to .
# Train data shape:  torch.Size([40000, 3072])
# Train labels shape:  torch.Size([40000])
# Validation data shape:  torch.Size([10000, 3072])
# Validation labels shape:  torch.Size([10000])
# Test data shape:  torch.Size([10000, 3072])
# Test labels shape:  torch.Size([10000])

# %% [markdown]
# ### Wrap all function into a Class
# We will use the class `TwoLayerNet` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are PyTorch tensors.

# %% [markdown]
# ### Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
import cpsc8810
from two_layer_net import TwoLayerNet

input_size = 3 * 32 * 32
hidden_size = 36
num_classes = 10

# fix random seed before we generate a set of parameters
cpsc8810.reset_seed(0)
net = TwoLayerNet(input_size, hidden_size, num_classes, dtype=data_dict['X_train'].dtype, device=data_dict['X_train'].device)

# Train the network
stats = net.train(data_dict['X_train'], data_dict['y_train'],
                  data_dict['X_val'], data_dict['y_val'],
                  num_iters=500, batch_size=1000,
                  learning_rate=1e-2, learning_rate_decay=0.95,
                  reg=0.25, verbose=True)

# Predict on the validation set
y_val_pred = net.predict(data_dict['X_val'])
val_acc = 100.0 * (y_val_pred == data_dict['y_val']).double().mean().item()
print('Validation accuracy: %.2f%%' % val_acc)
# Out:
# iteration 0 / 500: loss 2.302864
# iteration 100 / 500: loss 2.302695
# iteration 200 / 500: loss 2.302669
# iteration 300 / 500: loss 2.302552
# iteration 400 / 500: loss 2.302571
# Validation accuracy: 9.77%

# %% [markdown]
# ### Debug the training
# With the default parameters we provided above, you should get a validation accuracy less than 10% on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
from cpsc8810.a2_helpers import plot_stats

plot_stats(stats)

# %% [markdown]
# Similar to SVM and Softmax classifier, let's visualize the weights.

# %%
from cpsc8810.a2_helpers import show_net_weights 

show_net_weights(net)

# %% [markdown]
# ### What's wrong?
# Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.

# %% [markdown]
# #### Capacity?
# Our initial model has very similar performance on the training and validation sets. This suggests that the model is underfitting, and that its performance might improve if we were to increase its capacity.
#
# One way we can increase the capacity of a neural network model is to increase the size of its hidden layer. Here we investigate the effect of increasing the size of the hidden layer. The performance (as measured by validation-set accuracy) should increase as the size of the hidden layer increases; however it may show diminishing returns for larger layer sizes.

# %%
import cpsc8810
from cpsc8810.a2_helpers import plot_acc_curves
from two_layer_net import TwoLayerNet

hidden_sizes = [2, 8, 32, 128] 
lr = 0.1
reg = 0.001

stat_dict = {}
for hs in hidden_sizes:
  print('train with hidden size: {}'.format(hs))
  # fix random seed before we generate a set of parameters
  cpsc8810.reset_seed(0)
  net = TwoLayerNet(3 * 32 * 32, hs, 10, device=data_dict['X_train'].device, dtype=data_dict['X_train'].dtype)
  stats = net.train(data_dict['X_train'], data_dict['y_train'], data_dict['X_val'], data_dict['y_val'],
            num_iters=3000, batch_size=1000,
            learning_rate=lr, learning_rate_decay=0.95,
            reg=reg, verbose=False)
  stat_dict[hs] = stats

plot_acc_curves(stat_dict)
# Out:
# train with hidden size: 2
# train with hidden size: 8
# train with hidden size: 32
# train with hidden size: 128

# %% [markdown]
# #### Regularization?
# Another possible explanation for the small gap we saw between the train and validation accuracies of our model is regularization. In particular, if the regularization coefficient were too high then the model may be unable to fit the training data.
#
# We can investigate the phenomenon empirically by training a set of models with varying regularization strengths while fixing other hyperparameters.
#
# You should see that setting the regularization strength too high will harm the validation-set performance of the model:

# %%
import cpsc8810
from cpsc8810.a2_helpers import plot_acc_curves
from two_layer_net import TwoLayerNet

hs = 128
lr = 1.0
regs = [0, 1e-5, 1e-3, 1e-1]

stat_dict = {}
for reg in regs:
  print('train with regularization: {}'.format(reg))
  # fix random seed before we generate a set of parameters
  cpsc8810.reset_seed(0)
  net = TwoLayerNet(3 * 32 * 32, hs, 10, device=data_dict['X_train'].device, dtype=data_dict['X_train'].dtype)
  stats = net.train(data_dict['X_train'], data_dict['y_train'], data_dict['X_val'], data_dict['y_val'],
            num_iters=3000, batch_size=1000,
            learning_rate=lr, learning_rate_decay=0.95,
            reg=reg, verbose=False)
  stat_dict[reg] = stats

plot_acc_curves(stat_dict)
# Out:
# train with regularization: 0
# train with regularization: 1e-05
# train with regularization: 0.001
# train with regularization: 0.1

# %% [markdown]
# #### Learning Rate?
# Last but not least, we also want to see the effect of learning rate with respect to the performance.

# %%
import cpsc8810
from cpsc8810.a2_helpers import plot_acc_curves
from two_layer_net import TwoLayerNet

hs = 128
lrs = [1e-4, 1e-2, 1e0, 1e2]
reg = 1e-4

stat_dict = {}
for lr in lrs:
  print('train with learning rate: {}'.format(lr))
  # fix random seed before we generate a set of parameters
  cpsc8810.reset_seed(0)
  net = TwoLayerNet(3 * 32 * 32, hs, 10, device=data_dict['X_train'].device, dtype=data_dict['X_train'].dtype)
  stats = net.train(data_dict['X_train'], data_dict['y_train'], data_dict['X_val'], data_dict['y_val'],
            num_iters=3000, batch_size=1000,
            learning_rate=lr, learning_rate_decay=0.95,
            reg=reg, verbose=False)
  stat_dict[lr] = stats

plot_acc_curves(stat_dict)
# Out:
# train with learning rate: 0.0001
# train with learning rate: 0.01
# train with learning rate: 1.0
# train with learning rate: 100.0

# %% [markdown]
# ### Tune your hyperparameters
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, number of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Plots**. To guide your hyperparameter search, you might consider making auxiliary plots of training and validation performance as above, or plotting the results arising from different hyperparameter combinations as we did in the Linear Classifier notebook. You should feel free to plot any auxiliary results you need in order to find a good network, but we don't require any particular plots from you.
#
# **Approximate results**. To get full credit for the assignment, you should achieve a classification accuracy above 50% on the validation set.
#
# (Our best model gets a validation-set accuracy 56.44% -- did you beat us?)

# %%
import os
import cpsc8810
from two_layer_net import TwoLayerNet, find_best_net, nn_get_search_params

# running this model on float64 may needs more time, so set it as float32
cpsc8810.reset_seed(0)
data_dict = cpsc8810.data.preprocess_cifar10(dtype=torch.float32)

# store the best model into this 
cpsc8810.reset_seed(0)
best_net, best_stat, best_val_acc = find_best_net(data_dict, nn_get_search_params)
print(best_val_acc)

plot_stats(best_stat)

# save the best model
path = os.path.join(GOOGLE_DRIVE_PATH, 'nn_best_model.pt')
best_net.save(path)
# Out:
# lr 5.0000e-02 dr 9.5000e-01 h 64 reg 0.0000e+00 train accuracy: 0.3117 val accuracy: 0.3094
# lr 5.0000e-02 dr 9.5000e-01 h 64 reg 1.0000e-05 train accuracy: 0.3117 val accuracy: 0.3093
# lr 5.0000e-02 dr 9.5000e-01 h 64 reg 1.0000e-04 train accuracy: 0.3115 val accuracy: 0.3091
# lr 5.0000e-02 dr 9.5000e-01 h 64 reg 1.0000e-03 train accuracy: 0.3099 val accuracy: 0.3084
# lr 5.0000e-02 dr 9.5000e-01 h 64 reg 1.0000e-02 train accuracy: 0.2928 val accuracy: 0.2895
# lr 5.0000e-02 dr 9.5000e-01 h 64 reg 1.0000e-01 train accuracy: 0.2171 val accuracy: 0.2154
# lr 5.0000e-02 dr 9.5000e-01 h 128 reg 0.0000e+00 train accuracy: 0.3200 val accuracy: 0.3146
# lr 5.0000e-02 dr 9.5000e-01 h 128 reg 1.0000e-05 train accuracy: 0.3200 val accuracy: 0.3146
# lr 5.0000e-02 dr 9.5000e-01 h 128 reg 1.0000e-04 train accuracy: 0.3200 val accuracy: 0.3143
# lr 5.0000e-02 dr 9.5000e-01 h 128 reg 1.0000e-03 train accuracy: 0.3181 val accuracy: 0.3139
# lr 5.0000e-02 dr 9.5000e-01 h 128 reg 1.0000e-02 train accuracy: 0.3009 val accuracy: 0.2997
# lr 5.0000e-02 dr 9.5000e-01 h 128 reg 1.0000e-01 train accuracy: 0.2284 val accuracy: 0.2284
# lr 5.0000e-02 dr 9.5000e-01 h 256 reg 0.0000e+00 train accuracy: 0.3280 val accuracy: 0.3211
# lr 5.0000e-02 dr 9.5000e-01 h 256 reg 1.0000e-05 train accuracy: 0.3279 val accuracy: 0.3211
# lr 5.0000e-02 dr 9.5000e-01 h 256 reg 1.0000e-04 train accuracy: 0.3277 val accuracy: 0.3211
# lr 5.0000e-02 dr 9.5000e-01 h 256 reg 1.0000e-03 train accuracy: 0.3263 val accuracy: 0.3187
# lr 5.0000e-02 dr 9.5000e-01 h 256 reg 1.0000e-02 train accuracy: 0.3105 val accuracy: 0.3065
# lr 5.0000e-02 dr 9.5000e-01 h 256 reg 1.0000e-01 train accuracy: 0.2304 val accuracy: 0.2324
# lr 5.0000e-02 dr 9.5000e-01 h 512 reg 0.0000e+00 train accuracy: 0.3337 val accuracy: 0.3276
# lr 5.0000e-02 dr 9.5000e-01 h 512 reg 1.0000e-05 train accuracy: 0.3335 val accuracy: 0.3275
# lr 5.0000e-02 dr 9.5000e-01 h 512 reg 1.0000e-04 train accuracy: 0.3335 val accuracy: 0.3270
# lr 5.0000e-02 dr 9.5000e-01 h 512 reg 1.0000e-03 train accuracy: 0.3316 val accuracy: 0.3255
# lr 5.0000e-02 dr 9.5000e-01 h 512 reg 1.0000e-02 train accuracy: 0.3159 val accuracy: 0.3099
# lr 5.0000e-02 dr 9.5000e-01 h 512 reg 1.0000e-01 train accuracy: 0.2327 val accuracy: 0.2347
# lr 5.0000e-02 dr 1.0000e+00 h 64 reg 0.0000e+00 train accuracy: 0.4898 val accuracy: 0.4632
# lr 5.0000e-02 dr 1.0000e+00 h 64 reg 1.0000e-05 train accuracy: 0.4897 val accuracy: 0.4638
# lr 5.0000e-02 dr 1.0000e+00 h 64 reg 1.0000e-04 train accuracy: 0.4891 val accuracy: 0.4635
# lr 5.0000e-02 dr 1.0000e+00 h 64 reg 1.0000e-03 train accuracy: 0.4840 val accuracy: 0.4597
# lr 5.0000e-02 dr 1.0000e+00 h 64 reg 1.0000e-02 train accuracy: 0.4326 val accuracy: 0.4278
# lr 5.0000e-02 dr 1.0000e+00 h 64 reg 1.0000e-01 train accuracy: 0.2608 val accuracy: 0.2606
# lr 5.0000e-02 dr 1.0000e+00 h 128 reg 0.0000e+00 train accuracy: 0.4953 val accuracy: 0.4669
# lr 5.0000e-02 dr 1.0000e+00 h 128 reg 1.0000e-05 train accuracy: 0.4950 val accuracy: 0.4681
# lr 5.0000e-02 dr 1.0000e+00 h 128 reg 1.0000e-04 train accuracy: 0.4940 val accuracy: 0.4678
# lr 5.0000e-02 dr 1.0000e+00 h 128 reg 1.0000e-03 train accuracy: 0.4892 val accuracy: 0.4655
# lr 5.0000e-02 dr 1.0000e+00 h 128 reg 1.0000e-02 train accuracy: 0.4385 val accuracy: 0.4244
# lr 5.0000e-02 dr 1.0000e+00 h 128 reg 1.0000e-01 train accuracy: 0.2619 val accuracy: 0.2623
# lr 5.0000e-02 dr 1.0000e+00 h 256 reg 0.0000e+00 train accuracy: 0.4992 val accuracy: 0.4652
# lr 5.0000e-02 dr 1.0000e+00 h 256 reg 1.0000e-05 train accuracy: 0.4992 val accuracy: 0.4656
# lr 5.0000e-02 dr 1.0000e+00 h 256 reg 1.0000e-04 train accuracy: 0.4986 val accuracy: 0.4659
# lr 5.0000e-02 dr 1.0000e+00 h 256 reg 1.0000e-03 train accuracy: 0.4906 val accuracy: 0.4641
# lr 5.0000e-02 dr 1.0000e+00 h 256 reg 1.0000e-02 train accuracy: 0.4376 val accuracy: 0.4250
# lr 5.0000e-02 dr 1.0000e+00 h 256 reg 1.0000e-01 train accuracy: 0.2616 val accuracy: 0.2612
# lr 5.0000e-02 dr 1.0000e+00 h 512 reg 0.0000e+00 train accuracy: 0.5049 val accuracy: 0.4749
# lr 5.0000e-02 dr 1.0000e+00 h 512 reg 1.0000e-05 train accuracy: 0.5050 val accuracy: 0.4756
# lr 5.0000e-02 dr 1.0000e+00 h 512 reg 1.0000e-04 train accuracy: 0.5041 val accuracy: 0.4749
# lr 5.0000e-02 dr 1.0000e+00 h 512 reg 1.0000e-03 train accuracy: 0.4968 val accuracy: 0.4701
# lr 5.0000e-02 dr 1.0000e+00 h 512 reg 1.0000e-02 train accuracy: 0.4411 val accuracy: 0.4289
# lr 5.0000e-02 dr 1.0000e+00 h 512 reg 1.0000e-01 train accuracy: 0.2614 val accuracy: 0.2611
# lr 7.5000e-02 dr 9.5000e-01 h 64 reg 0.0000e+00 train accuracy: 0.3724 val accuracy: 0.3652
# lr 7.5000e-02 dr 9.5000e-01 h 64 reg 1.0000e-05 train accuracy: 0.3724 val accuracy: 0.3652
# lr 7.5000e-02 dr 9.5000e-01 h 64 reg 1.0000e-04 train accuracy: 0.3724 val accuracy: 0.3652
# lr 7.5000e-02 dr 9.5000e-01 h 64 reg 1.0000e-03 train accuracy: 0.3707 val accuracy: 0.3639
# lr 7.5000e-02 dr 9.5000e-01 h 64 reg 1.0000e-02 train accuracy: 0.3554 val accuracy: 0.3501
# lr 7.5000e-02 dr 9.5000e-01 h 64 reg 1.0000e-01 train accuracy: 0.2418 val accuracy: 0.2413
# lr 7.5000e-02 dr 9.5000e-01 h 128 reg 0.0000e+00 train accuracy: 0.3760 val accuracy: 0.3668
# lr 7.5000e-02 dr 9.5000e-01 h 128 reg 1.0000e-05 train accuracy: 0.3760 val accuracy: 0.3666
# lr 7.5000e-02 dr 9.5000e-01 h 128 reg 1.0000e-04 train accuracy: 0.3758 val accuracy: 0.3667
# lr 7.5000e-02 dr 9.5000e-01 h 128 reg 1.0000e-03 train accuracy: 0.3739 val accuracy: 0.3644
# lr 7.5000e-02 dr 9.5000e-01 h 128 reg 1.0000e-02 train accuracy: 0.3574 val accuracy: 0.3531
# lr 7.5000e-02 dr 9.5000e-01 h 128 reg 1.0000e-01 train accuracy: 0.2431 val accuracy: 0.2417
# lr 7.5000e-02 dr 9.5000e-01 h 256 reg 0.0000e+00 train accuracy: 0.3819 val accuracy: 0.3723
# lr 7.5000e-02 dr 9.5000e-01 h 256 reg 1.0000e-05 train accuracy: 0.3818 val accuracy: 0.3724
# lr 7.5000e-02 dr 9.5000e-01 h 256 reg 1.0000e-04 train accuracy: 0.3818 val accuracy: 0.3718
# lr 7.5000e-02 dr 9.5000e-01 h 256 reg 1.0000e-03 train accuracy: 0.3799 val accuracy: 0.3705
# lr 7.5000e-02 dr 9.5000e-01 h 256 reg 1.0000e-02 train accuracy: 0.3626 val accuracy: 0.3564
# lr 7.5000e-02 dr 9.5000e-01 h 256 reg 1.0000e-01 train accuracy: 0.2436 val accuracy: 0.2430
# lr 7.5000e-02 dr 9.5000e-01 h 512 reg 0.0000e+00 train accuracy: 0.3839 val accuracy: 0.3749
# lr 7.5000e-02 dr 9.5000e-01 h 512 reg 1.0000e-05 train accuracy: 0.3838 val accuracy: 0.3751
# lr 7.5000e-02 dr 9.5000e-01 h 512 reg 1.0000e-04 train accuracy: 0.3836 val accuracy: 0.3748
# lr 7.5000e-02 dr 9.5000e-01 h 512 reg 1.0000e-03 train accuracy: 0.3820 val accuracy: 0.3741
# lr 7.5000e-02 dr 9.5000e-01 h 512 reg 1.0000e-02 train accuracy: 0.3660 val accuracy: 0.3591
# lr 7.5000e-02 dr 9.5000e-01 h 512 reg 1.0000e-01 train accuracy: 0.2441 val accuracy: 0.2442
# lr 7.5000e-02 dr 1.0000e+00 h 64 reg 0.0000e+00 train accuracy: 0.5319 val accuracy: 0.4858
# lr 7.5000e-02 dr 1.0000e+00 h 64 reg 1.0000e-05 train accuracy: 0.5316 val accuracy: 0.4856
# lr 7.5000e-02 dr 1.0000e+00 h 64 reg 1.0000e-04 train accuracy: 0.5300 val accuracy: 0.4850
# lr 7.5000e-02 dr 1.0000e+00 h 64 reg 1.0000e-03 train accuracy: 0.5209 val accuracy: 0.4841
# lr 7.5000e-02 dr 1.0000e+00 h 64 reg 1.0000e-02 train accuracy: 0.4520 val accuracy: 0.4384
# lr 7.5000e-02 dr 1.0000e+00 h 64 reg 1.0000e-01 train accuracy: 0.2696 val accuracy: 0.2671
# lr 7.5000e-02 dr 1.0000e+00 h 128 reg 0.0000e+00 train accuracy: 0.5432 val accuracy: 0.4961
# lr 7.5000e-02 dr 1.0000e+00 h 128 reg 1.0000e-05 train accuracy: 0.5423 val accuracy: 0.4959
# lr 7.5000e-02 dr 1.0000e+00 h 128 reg 1.0000e-04 train accuracy: 0.5414 val accuracy: 0.4947
# lr 7.5000e-02 dr 1.0000e+00 h 128 reg 1.0000e-03 train accuracy: 0.5306 val accuracy: 0.4894
# lr 7.5000e-02 dr 1.0000e+00 h 128 reg 1.0000e-02 train accuracy: 0.4547 val accuracy: 0.4392
# lr 7.5000e-02 dr 1.0000e+00 h 128 reg 1.0000e-01 train accuracy: 0.2697 val accuracy: 0.2678
# lr 7.5000e-02 dr 1.0000e+00 h 256 reg 0.0000e+00 train accuracy: 0.5497 val accuracy: 0.5003
# lr 7.5000e-02 dr 1.0000e+00 h 256 reg 1.0000e-05 train accuracy: 0.5500 val accuracy: 0.5004
# lr 7.5000e-02 dr 1.0000e+00 h 256 reg 1.0000e-04 train accuracy: 0.5486 val accuracy: 0.4995
# lr 7.5000e-02 dr 1.0000e+00 h 256 reg 1.0000e-03 train accuracy: 0.5371 val accuracy: 0.4958
# lr 7.5000e-02 dr 1.0000e+00 h 256 reg 1.0000e-02 train accuracy: 0.4559 val accuracy: 0.4407
# lr 7.5000e-02 dr 1.0000e+00 h 256 reg 1.0000e-01 train accuracy: 0.2694 val accuracy: 0.2674
# lr 7.5000e-02 dr 1.0000e+00 h 512 reg 0.0000e+00 train accuracy: 0.5578 val accuracy: 0.5074
# lr 7.5000e-02 dr 1.0000e+00 h 512 reg 1.0000e-05 train accuracy: 0.5574 val accuracy: 0.5076
# lr 7.5000e-02 dr 1.0000e+00 h 512 reg 1.0000e-04 train accuracy: 0.5564 val accuracy: 0.5070
# lr 7.5000e-02 dr 1.0000e+00 h 512 reg 1.0000e-03 train accuracy: 0.5436 val accuracy: 0.4984
# lr 7.5000e-02 dr 1.0000e+00 h 512 reg 1.0000e-02 train accuracy: 0.4578 val accuracy: 0.4414
# lr 7.5000e-02 dr 1.0000e+00 h 512 reg 1.0000e-01 train accuracy: 0.2702 val accuracy: 0.2679
# lr 1.0000e-01 dr 9.5000e-01 h 64 reg 0.0000e+00 train accuracy: 0.4032 val accuracy: 0.3936
# lr 1.0000e-01 dr 9.5000e-01 h 64 reg 1.0000e-05 train accuracy: 0.4033 val accuracy: 0.3935
# lr 1.0000e-01 dr 9.5000e-01 h 64 reg 1.0000e-04 train accuracy: 0.4028 val accuracy: 0.3941
# lr 1.0000e-01 dr 9.5000e-01 h 64 reg 1.0000e-03 train accuracy: 0.4007 val accuracy: 0.3928
# lr 1.0000e-01 dr 9.5000e-01 h 64 reg 1.0000e-02 train accuracy: 0.3815 val accuracy: 0.3751
# lr 1.0000e-01 dr 9.5000e-01 h 64 reg 1.0000e-01 train accuracy: 0.2476 val accuracy: 0.2483
# lr 1.0000e-01 dr 9.5000e-01 h 128 reg 0.0000e+00 train accuracy: 0.4057 val accuracy: 0.3953
# lr 1.0000e-01 dr 9.5000e-01 h 128 reg 1.0000e-05 train accuracy: 0.4058 val accuracy: 0.3946
# lr 1.0000e-01 dr 9.5000e-01 h 128 reg 1.0000e-04 train accuracy: 0.4058 val accuracy: 0.3949
# lr 1.0000e-01 dr 9.5000e-01 h 128 reg 1.0000e-03 train accuracy: 0.4036 val accuracy: 0.3928
# lr 1.0000e-01 dr 9.5000e-01 h 128 reg 1.0000e-02 train accuracy: 0.3842 val accuracy: 0.3746
# lr 1.0000e-01 dr 9.5000e-01 h 128 reg 1.0000e-01 train accuracy: 0.2476 val accuracy: 0.2486
# lr 1.0000e-01 dr 9.5000e-01 h 256 reg 0.0000e+00 train accuracy: 0.4107 val accuracy: 0.4021
# lr 1.0000e-01 dr 9.5000e-01 h 256 reg 1.0000e-05 train accuracy: 0.4107 val accuracy: 0.4023
# lr 1.0000e-01 dr 9.5000e-01 h 256 reg 1.0000e-04 train accuracy: 0.4103 val accuracy: 0.4018
# lr 1.0000e-01 dr 9.5000e-01 h 256 reg 1.0000e-03 train accuracy: 0.4080 val accuracy: 0.3976
# lr 1.0000e-01 dr 9.5000e-01 h 256 reg 1.0000e-02 train accuracy: 0.3869 val accuracy: 0.3776
# lr 1.0000e-01 dr 9.5000e-01 h 256 reg 1.0000e-01 train accuracy: 0.2483 val accuracy: 0.2496
# lr 1.0000e-01 dr 9.5000e-01 h 512 reg 0.0000e+00 train accuracy: 0.4160 val accuracy: 0.4063
# lr 1.0000e-01 dr 9.5000e-01 h 512 reg 1.0000e-05 train accuracy: 0.4160 val accuracy: 0.4062
# lr 1.0000e-01 dr 9.5000e-01 h 512 reg 1.0000e-04 train accuracy: 0.4156 val accuracy: 0.4055
# lr 1.0000e-01 dr 9.5000e-01 h 512 reg 1.0000e-03 train accuracy: 0.4126 val accuracy: 0.4015
# lr 1.0000e-01 dr 9.5000e-01 h 512 reg 1.0000e-02 train accuracy: 0.3882 val accuracy: 0.3781
# lr 1.0000e-01 dr 9.5000e-01 h 512 reg 1.0000e-01 train accuracy: 0.2487 val accuracy: 0.2500
# lr 1.0000e-01 dr 1.0000e+00 h 64 reg 0.0000e+00 train accuracy: 0.5576 val accuracy: 0.4970
# lr 1.0000e-01 dr 1.0000e+00 h 64 reg 1.0000e-05 train accuracy: 0.5571 val accuracy: 0.4973
# lr 1.0000e-01 dr 1.0000e+00 h 64 reg 1.0000e-04 train accuracy: 0.5559 val accuracy: 0.4977
# lr 1.0000e-01 dr 1.0000e+00 h 64 reg 1.0000e-03 train accuracy: 0.5420 val accuracy: 0.4946
# lr 1.0000e-01 dr 1.0000e+00 h 64 reg 1.0000e-02 train accuracy: 0.4576 val accuracy: 0.4407
# lr 1.0000e-01 dr 1.0000e+00 h 64 reg 1.0000e-01 train accuracy: 0.2761 val accuracy: 0.2766
# lr 1.0000e-01 dr 1.0000e+00 h 128 reg 0.0000e+00 train accuracy: 0.5782 val accuracy: 0.5050
# lr 1.0000e-01 dr 1.0000e+00 h 128 reg 1.0000e-05 train accuracy: 0.5787 val accuracy: 0.5047
# lr 1.0000e-01 dr 1.0000e+00 h 128 reg 1.0000e-04 train accuracy: 0.5758 val accuracy: 0.5057
# lr 1.0000e-01 dr 1.0000e+00 h 128 reg 1.0000e-03 train accuracy: 0.5589 val accuracy: 0.5058
# lr 1.0000e-01 dr 1.0000e+00 h 128 reg 1.0000e-02 train accuracy: 0.4633 val accuracy: 0.4473
# lr 1.0000e-01 dr 1.0000e+00 h 128 reg 1.0000e-01 train accuracy: 0.2756 val accuracy: 0.2747
# lr 1.0000e-01 dr 1.0000e+00 h 256 reg 0.0000e+00 train accuracy: 0.5913 val accuracy: 0.5171
# lr 1.0000e-01 dr 1.0000e+00 h 256 reg 1.0000e-05 train accuracy: 0.5906 val accuracy: 0.5171
# lr 1.0000e-01 dr 1.0000e+00 h 256 reg 1.0000e-04 train accuracy: 0.5885 val accuracy: 0.5179
# lr 1.0000e-01 dr 1.0000e+00 h 256 reg 1.0000e-03 train accuracy: 0.5702 val accuracy: 0.5088
# lr 1.0000e-01 dr 1.0000e+00 h 256 reg 1.0000e-02 train accuracy: 0.4639 val accuracy: 0.4471
# lr 1.0000e-01 dr 1.0000e+00 h 256 reg 1.0000e-01 train accuracy: 0.2760 val accuracy: 0.2753
# lr 1.0000e-01 dr 1.0000e+00 h 512 reg 0.0000e+00 train accuracy: 0.5992 val accuracy: 0.5220
# lr 1.0000e-01 dr 1.0000e+00 h 512 reg 1.0000e-05 train accuracy: 0.5993 val accuracy: 0.5216
# lr 1.0000e-01 dr 1.0000e+00 h 512 reg 1.0000e-04 train accuracy: 0.5968 val accuracy: 0.5204
# lr 1.0000e-01 dr 1.0000e+00 h 512 reg 1.0000e-03 train accuracy: 0.5761 val accuracy: 0.5154
# lr 1.0000e-01 dr 1.0000e+00 h 512 reg 1.0000e-02 train accuracy: 0.4645 val accuracy: 0.4472
# lr 1.0000e-01 dr 1.0000e+00 h 512 reg 1.0000e-01 train accuracy: 0.2763 val accuracy: 0.2763
#
# The best model:
# Training accuracy: 0.5992, Validation accuracy: 0.5220
# lr 1.0000e-01 dr 1.0000e+00 h 512 reg 0.0000e+00
# 0.522
# Saved in drive/My Drive/Colab Notebooks/Computer Vision/Project 2/nn_best_model.pt

# %%
# Check the validation-set accuracy of your best model
y_val_preds = best_net.predict(data_dict['X_val'])
val_acc = 100 * (y_val_preds == data_dict['y_val']).double().mean().item()
print('Best val-set accuracy: %.2f%%' % val_acc)
# Out:
# Best val-set accuracy: 52.20%

# %%
from cpsc8810.a2_helpers import show_net_weights
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# ### Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set. To get full credit for the assignment, you should achieve over 50% classification accuracy on the test set.
#
# (Our best model gets 56.03% test-set accuracy -- did you beat us?)

# %%
y_test_preds = best_net.predict(data_dict['X_test'])
test_acc = 100 * (y_test_preds == data_dict['y_test']).double().mean().item()
print('Test accuracy: %.2f%%' % test_acc)
# Out:
# Test accuracy: 51.91%
